# %%
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
filenames = sorted(glob.glob('./data/inflammation*csv'))

for f in filenames:
    # check the file being processed
    print(f)
    #load data
    data = np.loadtxt(f, delimiter=',')
    
    #create figure
    fig = plt.figure(figsize=(10, 3))
    #creating subplot
    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)
   
    #adding dqta to subplot
    axes1.plot(data.max(axis=0), '-o', color='red')
    axes2.plot(data.min(axis=0), '-o', color='blue')
    axes3.plot(data.mean(axis=0), '-o', color='green')

    max_value = data.max(axis=0)
    min_value = data.min(axis=0)
    mean_value = data.mean(axis=0)
    #data/inflammation-01.csv
    #inflammation-01-max.csv
    output_file = 
    output_file_name_max = 
    output_file_name_min = 
    output_file_name_mean = 
    
    
    #save stats to files
    #np.savetxt("output/foo.csv", data ,delimiter=",")
    
    #set labels for subplots
    axes2.set_xlabel('Day')
    axes1.set_ylabel('Maximum')
    axes2.set_ylabel('Minimum')
    axes3.set_ylabel('Mean')

    fig.tight_layout()
    #plt.savefig('./figures/Plots_Inflammation-01.png')
    plt.show()
# Out:
# ./data\inflammation-01.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 22
#      18     axes2.plot(data.min(axis=0), '-o', color='blue')
#      19     axes3.plot(data.mean(axis=0), '-o', color='green')
#      20
#      21     #save stats to files
# ---> 22     np.savetxt("output/foo.csv", a, delimiter=",")
#      23
#      24     #set labels for subplots
#      25     axes2.set_xlabel('Day')
#
# NameError: name 'a' is not defined
